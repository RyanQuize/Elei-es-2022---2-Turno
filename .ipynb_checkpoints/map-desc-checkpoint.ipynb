# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_votacao = pd.read_csv('./dados_eleicaoBR/votacao_candidato_munzona_2022_BR.csv', sep=';', encoding='latin1')

df_votacao.head()
# Out:
#    DT_GERACAO HH_GERACAO  ANO_ELEICAO  CD_TIPO_ELEICAO    NM_TIPO_ELEICAO  \
# 0  10/04/2023   20:39:40         2022                2  Eleição Ordinária
# 1  10/04/2023   20:39:40         2022                2  Eleição Ordinária
# 2  10/04/2023   20:39:40         2022                2  Eleição Ordinária
# 3  10/04/2023   20:39:40         2022                2  Eleição Ordinária
# 4  10/04/2023   20:39:40         2022                2  Eleição Ordinária
#
#    NR_TURNO  CD_ELEICAO                  DS_ELEICAO  DT_ELEICAO  \
# 0         2         545  Eleição Geral Federal 2022  30/10/2022
# 1         2         545  Eleição Geral Federal 2022  30/10/2022
# 2         2         545  Eleição Geral Federal 2022  30/10/2022
# 3         2         545  Eleição Geral Federal 2022  30/10/2022
# 4         2         545  Eleição Geral Federal 2022  30/10/2022
#
#   TP_ABRANGENCIA  ... DS_COMPOSICAO_FEDERACAO  SQ_COLIGACAO  \
# 0              F  ...       PC do B / PT / PV  280001681359
# 1              F  ...       PC do B / PT / PV  280001681359
# 2              F  ...       PC do B / PT / PV  280001681359
# 3              F  ...       PC do B / PT / PV  280001681359
# 4              F  ...       PC do B / PT / PV  280001681359
#
#                     NM_COLIGACAO  \
# 0  COLIGAÇÃO BRASIL DA ESPERANÇA
# 1  COLIGAÇÃO BRASIL DA ESPERANÇA
# 2  COLIGAÇÃO BRASIL DA ESPERANÇA
# 3  COLIGAÇÃO BRASIL DA ESPERANÇA
# 4  COLIGAÇÃO BRASIL DA ESPERANÇA
#
#                              DS_COMPOSICAO_COLIGACAO ST_VOTO_EM_TRANSITO  \
# 0  (PT/PC do B/PV) / SOLIDARIEDADE / (PSOL/REDE) ...                   N
# 1  (PT/PC do B/PV) / SOLIDARIEDADE / (PSOL/REDE) ...                   N
# 2  (PT/PC do B/PV) / SOLIDARIEDADE / (PSOL/REDE) ...                   N
# 3  (PT/PC do B/PV) / SOLIDARIEDADE / (PSOL/REDE) ...                   N
# 4  (PT/PC do B/PV) / SOLIDARIEDADE / (PSOL/REDE) ...                   N
#
#    QT_VOTOS_NOMINAIS  NM_TIPO_DESTINACAO_VOTOS QT_VOTOS_NOMINAIS_VALIDOS  \
# 0               4372                    Válido                      4372
# 1              45956                    Válido                     45956
# 2              10468                    Válido                     10468
# 3               1795                    Válido                      1795
# 4              66182                    Válido                     66182
#
#    CD_SIT_TOT_TURNO  DS_SIT_TOT_TURNO
# 0                 1            ELEITO
# 1                 1            ELEITO
# 2                 1            ELEITO
# 3                 1            ELEITO
# 4                 1            ELEITO
#
# [5 rows x 44 columns]

# %%
df_votacao = df_votacao[df_votacao['NR_TURNO'] == 2]

# %%
df_votacao = df_votacao[df_votacao['SG_UF'] != 'ZZ']

# %%
df_votacao['CD_MUNICIPIO'].nunique()
# Out:
# 5570

# %%
df_votacao = df_votacao[['SG_UF', 'CD_MUNICIPIO', 'NM_MUNICIPIO', 'NR_CANDIDATO',
                        'NM_URNA_CANDIDATO', 'QT_VOTOS_NOMINAIS']]

df_votacao.head()
# Out:
#   SG_UF  CD_MUNICIPIO     NM_MUNICIPIO  NR_CANDIDATO NM_URNA_CANDIDATO  \
# 0    MS         91782  CHAPADÃO DO SUL            13              LULA
# 1    CE         13897        FORTALEZA            13              LULA
# 2    GO         95559        PORANGATU            13              LULA
# 3    GO         94498           MAMBAÍ            13              LULA
# 4    CE         13854            CRATO            13              LULA
#
#    QT_VOTOS_NOMINAIS
# 0               4372
# 1              45956
# 2              10468
# 3               1795
# 4              66182

# %%
df_votacao = df_votacao.groupby(['SG_UF', 'CD_MUNICIPIO', 'NM_MUNICIPIO', 'NR_CANDIDATO', 'NM_URNA_CANDIDATO']).sum().reset_index()

df_votacao.sample(4)
# Out:
#      SG_UF  CD_MUNICIPIO       NM_MUNICIPIO  NR_CANDIDATO NM_URNA_CANDIDATO  \
# 3712    MG         47635             LAVRAS            13              LULA
# 7313    RJ         58793              PIRAÍ            22    JAIR BOLSONARO
# 7378    RN         16047   CAIÇARA DO NORTE            13              LULA
# 8304    RS         87084  MONTE BELO DO SUL            13              LULA
#
#       QT_VOTOS_NOMINAIS
# 3712              27564
# 7313               8935
# 7378               2695
# 8304                450

# %%
df_votacao[df_votacao['NM_MUNICIPIO'] == 'SÃO PAULO']
# Out:
#       SG_UF  CD_MUNICIPIO NM_MUNICIPIO  NR_CANDIDATO NM_URNA_CANDIDATO  \
# 10722    SP         71072    SÃO PAULO            13              LULA
# 10723    SP         71072    SÃO PAULO            22    JAIR BOLSONARO
#
#        QT_VOTOS_NOMINAIS
# 10722            3677921
# 10723            3191484

# %%
df_votacao.sort_values(by='QT_VOTOS_NOMINAIS', ascending=False, inplace=True)

df_votacao.drop_duplicates(subset='CD_MUNICIPIO', keep='first', inplace=True)

df_votacao.head(10)
# Out:
#       SG_UF  CD_MUNICIPIO    NM_MUNICIPIO  NR_CANDIDATO NM_URNA_CANDIDATO  \
# 10722    SP         71072       SÃO PAULO            13              LULA
# 7369     RJ         60011  RIO DE JANEIRO            22    JAIR BOLSONARO
# 1054     BA         38490        SALVADOR            13              LULA
# 1607     DF         97012        BRASÍLIA            22    JAIR BOLSONARO
# 1376     CE         13897       FORTALEZA            13              LULA
# 2937     MG         41238  BELO HORIZONTE            22    JAIR BOLSONARO
# 6659     PR         75353        CURITIBA            22    JAIR BOLSONARO
# 309      AM          2550          MANAUS            22    JAIR BOLSONARO
# 5834     PE         25313          RECIFE            13              LULA
# 2013     GO         93734         GOIÂNIA            22    JAIR BOLSONARO
#
#        QT_VOTOS_NOMINAIS
# 10722            3677921
# 7369             1929209
# 1054             1089899
# 1607             1041331
# 1376              880559
# 2937              834548
# 6659              720322
# 309               692580
# 5834              558690
# 2013              513018

# %%
df_votacao.groupby('SG_UF')['QT_VOTOS_NOMINAIS'].sum().sort_values(ascending=False)
# Out:
# SG_UF
# SP    14998015
# MG     7139367
# BA     6108902
# RJ     5431420
# PR     4228456
# RS     3953544
# CE     3807891
# PE     3643103
# SC     3055310
# PA     2744946
# MA     2687855
# GO     2230454
# PB     1601953
# PI     1551383
# RN     1335038
# ES     1305803
# AM     1264960
# MT     1232167
# AL     1056464
# DF     1041331
# MS      891109
# SE      862951
# RO      633236
# TO      510257
# AC      289344
# AP      220590
# RR      215402
# Name: QT_VOTOS_NOMINAIS, dtype: int64

# %%
df_votacao[df_votacao['SG_UF'] == 'AC']
# Out:
#    SG_UF  CD_MUNICIPIO          NM_MUNICIPIO  NR_CANDIDATO NM_URNA_CANDIDATO  \
# 29    AC          1392            RIO BRANCO            22    JAIR BOLSONARO
# 15    AC          1074       CRUZEIRO DO SUL            22    JAIR BOLSONARO
# 31    AC          1457        SENA MADUREIRA            22    JAIR BOLSONARO
# 11    AC          1058             BRASILÉIA            22    JAIR BOLSONARO
# 39    AC          1538      SENADOR GUIOMARD            22    JAIR BOLSONARO
# 33    AC          1473              TARAUACÁ            22    JAIR BOLSONARO
# 5     AC          1023            PORTO ACRE            22    JAIR BOLSONARO
# 26    AC          1139                 FEIJÓ            13              LULA
# 23    AC          1112        EPITACIOLÂNDIA            22    JAIR BOLSONARO
# 19    AC          1090           MÂNCIO LIMA            22    JAIR BOLSONARO
# 37    AC          1511     PLÁCIDO DE CASTRO            22    JAIR BOLSONARO
# 17    AC          1082       RODRIGUES ALVES            22    JAIR BOLSONARO
# 25    AC          1120            ACRELÂNDIA            22    JAIR BOLSONARO
# 35    AC          1490                XAPURI            22    JAIR BOLSONARO
# 1     AC          1007                BUJARI            22    JAIR BOLSONARO
# 3     AC          1015              CAPIXABA            22    JAIR BOLSONARO
# 9     AC          1040  MARECHAL THAUMATURGO            22    JAIR BOLSONARO
# 41    AC          1554         MANOEL URBANO            22    JAIR BOLSONARO
# 43    AC          1570          ASSIS BRASIL            22    JAIR BOLSONARO
# 12    AC          1066          PORTO WALTER            13              LULA
# 20    AC          1104                JORDÃO            13              LULA
# 6     AC          1031   SANTA ROSA DO PURUS            13              LULA
#
#     QT_VOTOS_NOMINAIS  RESULTADO
# 29             142090       True
# 15              31936       True
# 31              13606       True
# 11               9593       True
# 39               9512       True
# 33               9067       True
# 5                7384       True
# 26               7113      False
# 23               6729       True
# 19               6331       True
# 37               6176       True
# 17               6011       True
# 25               5317       True
# 35               5217       True
# 1                4693       True
# 3                3963       True
# 9                3710       True
# 41               2889       True
# 43               2717       True
# 12               2093      False
# 20               1980      False
# 6                1217      False

# %%
df_ff = df_votacao.groupby(['SG_UF', 'NM_URNA_CANDIDATO'])['QT_VOTOS_NOMINAIS'].sum().reset_index()

# %%
df_ff.sort_values(by='QT_VOTOS_NOMINAIS', ascending=False, inplace=True)

# %%
df_ff.drop_duplicates(subset='SG_UF', keep='first', inplace=True)

# %%
df_ff.to_csv('mapa4.csv', sep=';', index=False)
